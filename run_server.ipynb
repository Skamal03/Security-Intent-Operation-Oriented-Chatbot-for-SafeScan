# %% [markdown]
# <a href="https://colab.research.google.com/github/Skamal03/Security-Intent-Operation-Oriented-Chatbot-for-SafeScan/blob/main/run_server.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
